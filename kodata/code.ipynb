# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd

# %%
pd.DataFrame({'yes':[50, 21], 'no':[13,1]},index=['A', 'B'])
# Out:
#    yes  no
# A   50  13
# B   21   1

# %%
titanic=pd.read_csv("./train.csv")

# %%
titanic[['PassengerId', 'Pclass']]
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
titanic[10: 15, 0, 1]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 10  female   4.0      1      1    PP 9549  16.7000    G6        S
# 11  female  58.0      0      0     113783  26.5500  C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500   NaN        S
# 13    male  39.0      1      5     347082  31.2750   NaN        S
# 14  female  14.0      0      0     350406   7.8542   NaN        S

# %%
titanic.iloc[100:116]
# Out:
# 10    female
# 11    female
# 12      male
# 13      male
# 14    female
# Name: Sex, dtype: str

# %%
titanic.iloc[10: 15]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 10  female   4.0      1      1    PP 9549  16.7000    G6        S
# 11  female  58.0      0      0     113783  26.5500  C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500   NaN        S
# 13    male  39.0      1      5     347082  31.2750   NaN        S
# 14  female  14.0      0      0     350406   7.8542   NaN        S

# %%
titanic.loc[10:15, ["PassengerId", "Sex"]]
# Out:
#     PassengerId     Sex
# 10           11  female
# 11           12  female
# 12           13    male
# 13           14    male
# 14           15  female
# 15           16  female

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.Age <= 20
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic[titanic.Age <= 20]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 12            13         0       3        Saundercock, Mr. William Henry
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# ..           ...       ...     ...                                   ...
# 869          870         1       3       Johnson, Master. Harold Theodor
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3         Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                  Petroff, Mr. Nedelio
# 887          888         1       1          Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
titanic[titanic.Age <= 20]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
titanic[titanic.Sex == "Male"]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic[(titanic.Age <= 20) & (titanic.Embarked=='s')]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic[(titanic.Embarked.isin(['s', 'c']))]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic.Age.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic[titanic.Age.isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic = titanic[titanic.Age.notnull()]

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   714.000000  714.000000  714.000000  714.000000  714.000000
# mean    448.582633    0.406162    2.236695   29.699118    0.512605
# std     259.119524    0.491460    0.838250   14.526497    0.929783
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     222.250000    0.000000    1.000000   20.125000    0.000000
# 50%     445.000000    0.000000    2.000000   28.000000    0.000000
# 75%     677.750000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  714.000000  714.000000
# mean     0.431373   34.694514
# std      0.853289   52.918930
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.741700
# 75%      1.000000   33.375000
# max      6.000000  512.329200

# %%
titanic.describe()['PassengerId']
# Out:
# count    714.000000
# mean     448.582633
# std      259.119524
# min        1.000000
# 25%      222.250000
# 50%      445.000000
# 75%      677.750000
# max      891.000000
# Name: PassengerId, dtype: float64

# %%
titanic.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
titanic.Survived.value_counts()
# Out:
# Survived
# 0    424
# 1    290
# Name: count, dtype: int64

# %%
titanic.Sex.value_counts()
# Out:
# Sex
# male      453
# female    261
# Name: count, dtype: int64

# %%
titanic.Name.map(lambda n : 'Je suis '+ n)
# Out:
# 0                        Je suis Braund, Mr. Owen Harris
# 1      Je suis Cumings, Mrs. John Bradley (Florence B...
# 2                         Je suis Heikkinen, Miss. Laina
# 3      Je suis Futrelle, Mrs. Jacques Heath (Lily May...
# 4                       Je suis Allen, Mr. William Henry
#                              ...
# 885         Je suis Rice, Mrs. William (Margaret Norton)
# 886                        Je suis Montvila, Rev. Juozas
# 887                 Je suis Graham, Miss. Margaret Edith
# 889                        Je suis Behr, Mr. Karl Howell
# 890                          Je suis Dooley, Mr. Patrick
# Name: Name, Length: 714, dtype: str

# %%
titanic.Sex.map(lambda x: 1 if x == 'male' else 0)
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 885    0
# 886    1
# 887    0
# 889    1
# 890    1
# Name: Sex, Length: 714, dtype: int64

# %%
titanic.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 885    female
# 886      male
# 887    female
# 889      male
# 890      male
# Name: Sex, Length: 714, dtype: str

# %%
titanic['Sex_modif'] = titanic.Sex.map(lambda x: 1 if x == 'male' else 0)

# %%
titanic.Sex_modif
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 885    0
# 886    1
# 887    0
# 889    1
# 890    1
# Name: Sex_modif, Length: 714, dtype: int64

# %%
def introduce(row):
	row['salutation'] = "Je suis "+row.Name+". J'ai "+str(row.Age)+" ans"
	return row

titanic.apply(introduce, axis="columns")['salutation']
# Out:
# 0         Je suis Braund, Mr. Owen Harris. J'ai 22.0 ans
# 1      Je suis Cumings, Mrs. John Bradley (Florence B...
# 2          Je suis Heikkinen, Miss. Laina. J'ai 26.0 ans
# 3      Je suis Futrelle, Mrs. Jacques Heath (Lily May...
# 4        Je suis Allen, Mr. William Henry. J'ai 35.0 ans
#                              ...
# 885    Je suis Rice, Mrs. William (Margaret Norton). ...
# 886         Je suis Montvila, Rev. Juozas. J'ai 27.0 ans
# 887    Je suis Graham, Miss. Margaret Edith. J'ai 19....
# 889         Je suis Behr, Mr. Karl Howell. J'ai 26.0 ans
# 890           Je suis Dooley, Mr. Patrick. J'ai 32.0 ans
# Name: salutation, Length: 714, dtype: str

# %%
titanic.groupby(['Sex']).Age.min()
# Out:
# Sex
# female    0.75
# male      0.42
# Name: Age, dtype: float64

# %%
titanic.groupby(['Sex', 'Embarked']).Age.mean()
# Out:
# Sex     Embarked
# female  C           28.344262
#         Q           24.291667
#         S           27.771505
# male    C           32.998841
#         Q           30.937500
#         S           30.291440
# Name: Age, dtype: float64

# %%
titanic.groupby(['Embarked']).apply(lambda df: df.iloc[:3])
# Out:
#              PassengerId  Survived  Pclass  \
# Embarked
# C        1             2         1       1
#          9            10         1       2
#          30           31         0       1
# Q        16           17         0       3
#          22           23         1       3
#          44           45         1       3
# S        0             1         0       3
#          2             3         1       3
#          3             4         1       1
#
#                                                           Name     Sex   Age  \
# Embarked
# C        1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#          9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#          30                           Uruchurtu, Don. Manuel E    male  40.0
# Q        16                               Rice, Master. Eugene    male   2.0
#          22                        McGowan, Miss. Anna "Annie"  female  15.0
# ...

# %%
titanic.Sex.replace('male', 'm').replace('female', 'f')
# Out:
# 0           m
# 1      female
# 2      female
# 3      female
# 4           m
#         ...
# 885    female
# 886         m
# 887    female
# 889         m
# 890         m
# Name: Sex, Length: 714, dtype: str

# %%
titanic.Sex.replace('male', 'm').replace('female', 'f')
# Out:
# 0      m
# 1      f
# 2      f
# 3      f
# 4      m
#       ..
# 885    f
# 886    m
# 887    f
# 889    m
# 890    m
# Name: Sex, Length: 714, dtype: str

# %%
titanic.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 885    female
# 886      male
# 887    female
# 889      male
# 890      male
# Name: Sex, Length: 714, dtype: str
